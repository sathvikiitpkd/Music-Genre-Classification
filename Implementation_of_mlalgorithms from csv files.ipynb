# %%
import pandas as pd

# %%
df = pd.read_csv('features_30_sec.csv')
df
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0    blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1    blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2    blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3    blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4    blues.00004.wav  661794          0.308526         0.087841  0.091529
# ..               ...     ...               ...              ...       ...
# 995   rock.00095.wav  661794          0.352063         0.080487  0.079486
# 996   rock.00096.wav  661794          0.398687         0.075086  0.076458
# 997   rock.00097.wav  661794          0.432142         0.075268  0.081651
# 998   rock.00098.wav  661794          0.362485         0.091506  0.083860
# 999   rock.00099.wav  661794          0.358401         0.085884  0.054454
#
#       rms_var  spectral_centroid_mean  spectral_centroid_var  \
# ...

# %%
df = df.iloc[0:, 1:]
x = df.loc[:, df.columns != 'label']
y = df['label']
x
# Out:
#      length  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0    661794          0.350088         0.088757  0.130228  0.002827
# 1    661794          0.340914         0.094980  0.095948  0.002373
# 2    661794          0.363637         0.085275  0.175570  0.002746
# 3    661794          0.404785         0.093999  0.141093  0.006346
# 4    661794          0.308526         0.087841  0.091529  0.002303
# ..      ...               ...              ...       ...       ...
# 995  661794          0.352063         0.080487  0.079486  0.000345
# 996  661794          0.398687         0.075086  0.076458  0.000588
# 997  661794          0.432142         0.075268  0.081651  0.000322
# 998  661794          0.362485         0.091506  0.083860  0.001211
# 999  661794          0.358401         0.085884  0.054454  0.000336
#
#      spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0               1784.165850          129774.064525              2002.449060
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
X
# Out:
#        length  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0    0.113487          0.362279         0.695468  0.318188  0.101983
# 1    0.113487          0.343622         0.793392  0.230894  0.085580
# 2    0.113487          0.389832         0.640692  0.433652  0.099064
# 3    0.113487          0.473508         0.777954  0.345856  0.229160
# 4    0.113487          0.277759         0.681062  0.219641  0.083075
# ..        ...               ...              ...       ...       ...
# 995  0.113487          0.366294         0.565355  0.188974  0.012317
# 996  0.113487          0.461109         0.480368  0.181264  0.021099
# 997  0.113487          0.529141         0.483246  0.194487  0.011492
# 998  0.113487          0.387488         0.738721  0.200112  0.043603
# 999  0.113487          0.379184         0.650272  0.125230  0.011982
#
#      spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
nb = GaussianNB()
nb.fit(X_train, y_train)
preds = nb.predict(X_test)
print('Accuracy of the GaussianNB Model is ', accuracy_score(y_test, preds), '\n')

plt.figure(figsize = (16, 9))
sns.heatmap(confusion_matrix(y_test, preds), cmap="hsv", annot=True, 
            xticklabels = ["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"],
           yticklabels=["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"]);
# Out:
# Accuracy of the GaussianNB Model is  0.49

# %%
knn = KNeighborsClassifier(n_neighbors=20)
knn.fit(X_train, y_train)
preds = knn.predict(X_test)
print('Accuracy of the KNeighborsClassifier Model is ', accuracy_score(y_test, preds), '\n')

plt.figure(figsize = (16, 9))
sns.heatmap(confusion_matrix(y_test, preds), cmap="hsv", annot=True, 
            xticklabels = ["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"],
           yticklabels=["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"]);
# Out:
# Accuracy of the KNeighborsClassifier Model is  0.59

# %%
lr = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial')
lr.fit(X_train, y_train)
preds = lr.predict(X_test)
print('Accuracy of the LogisticRegression Model is ', accuracy_score(y_test, preds), '\n')

plt.figure(figsize = (16, 9))
sns.heatmap(confusion_matrix(y_test, preds), cmap="hsv", annot=True, 
            xticklabels = ["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"],
           yticklabels=["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"]);
# Out:
# /home/sathvik/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy of the LogisticRegression Model is  0.62

# %%
sgd = SGDClassifier(max_iter=3000, random_state=5)
sgd.fit(X_train, y_train)
preds = sgd.predict(X_test)
print('Accuracy of the SGDClassifier Model is ', accuracy_score(y_test, preds), '\n')

plt.figure(figsize = (16, 9))
sns.heatmap(confusion_matrix(y_test, preds), cmap="hsv", annot=True, 
            xticklabels = ["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"],
           yticklabels=["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"]);
# Out:
# Accuracy of the SGDClassifier Model is  0.6266666666666667

# %%
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
preds = tree.predict(X_test)
print('Accuracy of the DecisionTreeClassifier Model is ', accuracy_score(y_test, preds), '\n')

plt.figure(figsize = (16, 9))
sns.heatmap(confusion_matrix(y_test, preds), cmap="hsv", annot=True, 
            xticklabels = ["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"],
           yticklabels=["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"]);
# Out:
# Accuracy of the DecisionTreeClassifier Model is  0.5666666666666667

# %%
rf = RandomForestClassifier(n_estimators=1000, max_depth=10, random_state=0)
rf.fit(X_train, y_train)
preds = rf.predict(X_test)
print('Accuracy of the RandomForestClassifier Model is ', accuracy_score(y_test, preds), '\n')

plt.figure(figsize = (16, 9))
sns.heatmap(confusion_matrix(y_test, preds), cmap="hsv", annot=True, 
            xticklabels = ["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"],
           yticklabels=["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"]);
# Out:
# Accuracy of the RandomForestClassifier Model is  0.7366666666666667

# %%
svm = SVC(decision_function_shape="ovo")
svm.fit(X_train, y_train)
preds = svm.predict(X_test)
print('Accuracy of the SVM Model is ', accuracy_score(y_test, preds), '\n')

plt.figure(figsize = (16, 9))
sns.heatmap(confusion_matrix(y_test, preds), cmap="hsv", annot=True, 
            xticklabels = ["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"],
           yticklabels=["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"]);
# Out:
# Accuracy of the SVM Model is  0.6433333333333333
